# %%
#J48 Attribute importance
import pandas as pd
import numpy as np
import os

directory_in_str = 'C:/Users/Alex/Documents/Uni_Mannheim/07_Masterarbeit/Masterthesis-Coding/JavaDevelopment/GMKT/logs/hotel/learning'
directory = os.fsencode(directory_in_str)

dict_dim = {'Attribute_SimilarityMeasure_Odds_importance_SimpleLogistic' : 'AttributeSimilarityMeasure',
            'Attribute_Odds_importance_SimpleLogistic' : 'Attribute',
            'Attribute_importance_J48': 'Attribute',
            'AttributeSimilarityMeasure_importance_J48': 'AttributeSimilarityMeasure',
            'FeatureThreshold_importance_J48' : 'FeatureThreshold',
            'FeatureThreshold_Odds_importance_SimpleLogistic': 'FeatureThreshold',
            'Feature_importance_J48': 'Feature',
            'Feature_Odds_importance_SimpleLogistic': 'Feature',
            'SplitThreshold_importance_J48': 'SplitThreshold'}
for key in dict_dim:
    dfMatchingLog = pd.DataFrame()
    for file in filter(os.path.isdir, os.listdir(directory)):
        filename = os.fsdecode(file)
        #display(type(file))
        #if not '.' in filename:
        extended_directory_str = directory_in_str + '/' + filename + '/matchingRule'
        extended_directory = os.fsencode(extended_directory_str)
        dim_found = []
        try:
            for logFile in os.listdir(extended_directory):
                logFileName = os.fsdecode(logFile)
                if key in logFileName:
                    if key not in dim_found:
                        dim_found.append(key)
                        fullLogFilePath = filename + '/matchingRule/' + logFileName
                        dfNewMatchingLog = pd.read_csv(fullLogFilePath, sep=',', encoding='utf-8')
                        dfMatchingLog = dfMatchingLog.append(dfNewMatchingLog)
        except FileNotFoundError:
            continue
    
    if 'SimpleLogistic' in key:
        dfMatchingLog['logOdds'] = np.log(dfMatchingLog['Odds'])
        del dfMatchingLog['Odds']
    display(key)
    dfMatchingLogMean = dfMatchingLog.groupby(by=dict_dim[key]).mean()
    dfMatchingLogMean.columns = [col + '_mean' for col in dfMatchingLogMean.columns]

    dfMatchingLogMeanStd = dfMatchingLog.groupby(by=dict_dim[key]).agg(np.std, ddof=0)
    dfMatchingLogMeanStd.columns = [col + '_std' for col in dfMatchingLogMeanStd.columns]
    
    dfMatchingLogMean['Topic'] = 'Hotel'
    csvName = key + '_hotel.csv' 
    
    if 'SimpleLogistic' in key:
        dfMatchingLogMean = dfMatchingLogMean.merge(dfMatchingLogMeanStd, left_index=True, right_index=True).sort_values(by=['logOdds_mean'],ascending=False)
        dfMatchingLogMean = dfMatchingLogMean.round(3)
        display(dfMatchingLogMean)
        dfMatchingLogMean.to_csv(csvName, sep=',')
        print(dfMatchingLogMean.to_latex())
    else:
        dfMatchingLogMean = dfMatchingLogMean.merge(dfMatchingLogMeanStd, left_index=True, right_index=True).sort_values(by=['GainRatioImportance_mean'],ascending=False)
        dfMatchingLogMean = dfMatchingLogMean.round(3)
        display(dfMatchingLogMean)
        dfMatchingLogMean.to_csv(csvName, sep=',')
        print(dfMatchingLogMean.to_latex())
# Out:
# C:\Users\Alex\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:20: DeprecationWarning: The Windows bytes API has been deprecated, use Unicode filenames instead
# C:\Users\Alex\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:28: DeprecationWarning: The Windows bytes API has been deprecated, use Unicode filenames instead
# 'Attribute_Odds_importance_SimpleLogistic'
#                             Rank_mean  logOdds_mean  Topic  Rank_std  \
# Attribute
# streetaddress                   2.000         5.501  Hotel     0.816
# all                             1.333         4.430  Hotel     0.471
# postalcode                      4.000         2.011  Hotel     0.000
# infrequent_part_hotel_name      2.000         1.229  Hotel     0.000
# frequent_part_hotel_name        3.000         0.035  Hotel     1.000
# hotel_name                      3.000        -4.550  Hotel     1.414
#
#                             logOdds_std
# Attribute
# streetaddress                     3.865
# all                               1.937
# postalcode                        0.000
# infrequent_part_hotel_name        0.000
# frequent_part_hotel_name          1.218
# hotel_name                        7.665
# \begin{tabular}{lrrlrr}
# \toprule
# {} &  Rank\_mean &  logOdds\_mean &  Topic &  Rank\_std &  logOdds\_std \\
# Attribute                  &            &               &        &           &              \\
# \midrule
# streetaddress              &      2.000 &         5.501 &  Hotel &     0.816 &        3.865 \\
# all                        &      1.333 &         4.430 &  Hotel &     0.471 &        1.937 \\
# postalcode                 &      4.000 &         2.011 &  Hotel &     0.000 &        0.000 \\
# infrequent\_part\_hotel\_name &      2.000 &         1.229 &  Hotel &     0.000 &        0.000 \\
# frequent\_part\_hotel\_name   &      3.000 &         0.035 &  Hotel &     1.000 &        1.218 \\
# hotel\_name                 &      3.000 &        -4.550 &  Hotel &     1.414 &        7.665 \\
# \bottomrule
# \end{tabular}
# 'AttributeSimilarityMeasure_importance_J48'
#                                              Rank_mean  \
# AttributeSimilarityMeasure
# BagOfWordsContainment~all                            2
# JaccardOnBiGrams~frequent_part_hotel_name            1
# JaccardOnBiGrams~hotel_name                          2
# JaroWinkler~postalcode                               2
# Jaccard~streetaddress                                2
# Equal~infrequent_part_hotel_name                     2
# JaccardOnBiGrams~infrequent_part_hotel_name          3
# Jaccard~infrequent_part_hotel_name                   2
# Jaccard~addresslocality                              5
# JaccardOnBiGrams~streetaddress                       6
#
#                                              GainRatioImportance_mean  Topic  \
# AttributeSimilarityMeasure
# BagOfWordsContainment~all                                       0.522  Hotel
# JaccardOnBiGrams~frequent_part_hotel_name                       0.402  Hotel
# JaccardOnBiGrams~hotel_name                                     0.272  Hotel
# JaroWinkler~postalcode                                          0.267  Hotel
# Jaccard~streetaddress                                           0.212  Hotel
# Equal~infrequent_part_hotel_name                                0.124  Hotel
# JaccardOnBiGrams~infrequent_part_hotel_name                     0.109  Hotel
# Jaccard~infrequent_part_hotel_name                              0.043  Hotel
# Jaccard~addresslocality                                         0.010  Hotel
# JaccardOnBiGrams~streetaddress                                  0.005  Hotel
#
#                                              Rank_std  GainRatioImportance_std
# AttributeSimilarityMeasure
# BagOfWordsContainment~all                       1.414                    0.356
# JaccardOnBiGrams~frequent_part_hotel_name       0.000                    0.000
# JaccardOnBiGrams~hotel_name                     1.000                    0.241
# JaroWinkler~postalcode                          0.000                    0.000
# Jaccard~streetaddress                           0.000                    0.000
# Equal~infrequent_part_hotel_name                0.000                    0.000
# JaccardOnBiGrams~infrequent_part_hotel_name     0.000                    0.000
# Jaccard~infrequent_part_hotel_name              0.000                    0.000
# Jaccard~addresslocality                         0.000                    0.000
# JaccardOnBiGrams~streetaddress                  0.000                    0.000
# \begin{tabular}{lrrlrr}
# \toprule
# {} &  Rank\_mean &  GainRatioImportance\_mean &  Topic &  Rank\_std &  GainRatioImportance\_std \\
# AttributeSimilarityMeasure                  &            &                           &        &           &                          \\
# \midrule
# BagOfWordsContainment\textasciitilde all                   &          2 &                     0.522 &  Hotel &     1.414 &                    0.356 \\
# JaccardOnBiGrams\textasciitilde frequent\_part\_hotel\_name   &          1 &                     0.402 &  Hotel &     0.000 &                    0.000 \\
# JaccardOnBiGrams\textasciitilde hotel\_name                 &          2 &                     0.272 &  Hotel &     1.000 &                    0.241 \\
# JaroWinkler\textasciitilde postalcode                      &          2 &                     0.267 &  Hotel &     0.000 &                    0.000 \\
# Jaccard\textasciitilde streetaddress                       &          2 &                     0.212 &  Hotel &     0.000 &                    0.000 \\
# Equal\textasciitilde infrequent\_part\_hotel\_name            &          2 &                     0.124 &  Hotel &     0.000 &                    0.000 \\
# JaccardOnBiGrams\textasciitilde infrequent\_part\_hotel\_name &          3 &                     0.109 &  Hotel &     0.000 &                    0.000 \\
# Jaccard\textasciitilde infrequent\_part\_hotel\_name          &          2 &                     0.043 &  Hotel &     0.000 &                    0.000 \\
# Jaccard\textasciitilde addresslocality                     &          5 &                     0.010 &  Hotel &     0.000 &                    0.000 \\
# JaccardOnBiGrams\textasciitilde streetaddress              &          6 &                     0.005 &  Hotel &     0.000 &                    0.000 \\
# \bottomrule
# \end{tabular}
# 'Attribute_importance_J48'
#                             Rank_mean  GainRatioImportance_mean  Topic  \
# Attribute
# all                             2.000                     0.522  Hotel
# frequent_part_hotel_name        1.000                     0.402  Hotel
# hotel_name                      2.000                     0.272  Hotel
# postalcode                      2.000                     0.267  Hotel
# streetaddress                   2.000                     0.218  Hotel
# infrequent_part_hotel_name      2.333                     0.092  Hotel
# addresslocality                 5.000                     0.010  Hotel
#
#                             Rank_std  GainRatioImportance_std
# Attribute
# all                            1.414                    0.356
# frequent_part_hotel_name       0.000                    0.000
# hotel_name                     1.000                    0.241
# postalcode                     0.000                    0.000
# streetaddress                  0.000                    0.000
# infrequent_part_hotel_name     0.471                    0.035
# addresslocality                0.000                    0.000
# \begin{tabular}{lrrlrr}
# \toprule
# {} &  Rank\_mean &  GainRatioImportance\_mean &  Topic &  Rank\_std &  GainRatioImportance\_std \\
# Attribute                  &            &                           &        &           &                          \\
# \midrule
# all                        &      2.000 &                     0.522 &  Hotel &     1.414 &                    0.356 \\
# frequent\_part\_hotel\_name   &      1.000 &                     0.402 &  Hotel &     0.000 &                    0.000 \\
# hotel\_name                 &      2.000 &                     0.272 &  Hotel &     1.000 &                    0.241 \\
# postalcode                 &      2.000 &                     0.267 &  Hotel &     0.000 &                    0.000 \\
# streetaddress              &      2.000 &                     0.218 &  Hotel &     0.000 &                    0.000 \\
# infrequent\_part\_hotel\_name &      2.333 &                     0.092 &  Hotel &     0.471 &                    0.035 \\
# addresslocality            &      5.000 &                     0.010 &  Hotel &     0.000 &                    0.000 \\
# \bottomrule
# \end{tabular}
# 'Attribute_SimilarityMeasure_Odds_importance_SimpleLogistic'
#                                              Rank_mean  logOdds_mean  Topic  \
# AttributeSimilarityMeasure
# JaccardOnBiGrams~hotel_name                          1         3.537  Hotel
# Jaccard~hotel_name                                   1         2.760  Hotel
# JaccardOnBiGrams~streetaddress                       2         2.609  Hotel
# BagOfWordsContainment~all                            3         1.692  Hotel
# JaccardOnBiGrams~frequent_part_hotel_name            2         1.253  Hotel
# JaccardOnBiGrams~infrequent_part_hotel_name          4         1.229  Hotel
# Jaro~frequent_part_hotel_name                        5        -1.183  Hotel
# FirstCharacter~streetaddress                         6        -1.812  Hotel
# JaroWinkler~hotel_name                               7       -11.214  Hotel
#
#                                              Rank_std  logOdds_std
# AttributeSimilarityMeasure
# JaccardOnBiGrams~hotel_name                       0.0          0.0
# Jaccard~hotel_name                                0.0          0.0
# JaccardOnBiGrams~streetaddress                    0.0          0.0
# BagOfWordsContainment~all                         0.0          0.0
# JaccardOnBiGrams~frequent_part_hotel_name         0.0          0.0
# JaccardOnBiGrams~infrequent_part_hotel_name       0.0          0.0
# Jaro~frequent_part_hotel_name                     0.0          0.0
# FirstCharacter~streetaddress                      0.0          0.0
# JaroWinkler~hotel_name                            0.0          0.0
# \begin{tabular}{lrrlrr}
# \toprule
# {} &  Rank\_mean &  logOdds\_mean &  Topic &  Rank\_std &  logOdds\_std \\
# AttributeSimilarityMeasure                  &            &               &        &           &              \\
# \midrule
# JaccardOnBiGrams\textasciitilde hotel\_name                 &          1 &         3.537 &  Hotel &       0.0 &          0.0 \\
# Jaccard\textasciitilde hotel\_name                          &          1 &         2.760 &  Hotel &       0.0 &          0.0 \\
# JaccardOnBiGrams\textasciitilde streetaddress              &          2 &         2.609 &  Hotel &       0.0 &          0.0 \\
# BagOfWordsContainment\textasciitilde all                   &          3 &         1.692 &  Hotel &       0.0 &          0.0 \\
# JaccardOnBiGrams\textasciitilde frequent\_part\_hotel\_name   &          2 &         1.253 &  Hotel &       0.0 &          0.0 \\
# JaccardOnBiGrams\textasciitilde infrequent\_part\_hotel\_name &          4 &         1.229 &  Hotel &       0.0 &          0.0 \\
# Jaro\textasciitilde frequent\_part\_hotel\_name               &          5 &        -1.183 &  Hotel &       0.0 &          0.0 \\
# FirstCharacter\textasciitilde streetaddress                &          6 &        -1.812 &  Hotel &       0.0 &          0.0 \\
# JaroWinkler\textasciitilde hotel\_name                      &          7 &       -11.214 &  Hotel &       0.0 &          0.0 \\
# \bottomrule
# \end{tabular}
# 'Feature_Odds_importance_SimpleLogistic'
#                                                     Rank_mean  logOdds_mean  \
# Feature
# [175] Levenshtein~streetaddress-T:0.4/S:true/B:...      1.000         7.889
# [260] BagOfWordsContainment~all-T:0.4/L:true            2.000         4.430
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...      1.000         3.537
# [279] Jaccard~hotel_name-T:0.2/S:true/B:false/L...      1.000         2.760
# [194] JaccardOnBiGrams~streetaddress-T:0.2/S:fa...      2.667         2.688
# [282] JaccardOnBiGrams~hotel_name-T:0.0/S:true/...      3.000         2.682
# [281] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...      3.000         2.388
# [178] Levenshtein~streetaddress-T:0.2/S:false/B...      4.000         2.365
# [278] Jaccard~hotel_name-T:0.2/S:false/B:true/L...      5.000         2.099
# [218] Levenshtein~postalcode-T:0.4/S:true/B:tru...      5.000         2.011
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...      2.000         1.253
# [108] JaccardOnBiGrams~infrequent_part_hotel_na...      4.000         1.229
# [38] Jaro~frequent_part_hotel_name-T:0.8/S:true...      5.000        -1.183
# [197] FirstCharacter~streetaddress-T:0.0/S:fals...      6.000        -1.812
# [296] JaroWinkler~hotel_name-T:0.2/S:true/B:fal...      7.000       -11.214
# [301] Jaro~hotel_name-T:0.6/S:true/B:true/L:true        6.000       -20.451
#
#                                                     Topic  Rank_std  \
# Feature
# [175] Levenshtein~streetaddress-T:0.4/S:true/B:...  Hotel     0.000
# [260] BagOfWordsContainment~all-T:0.4/L:true        Hotel     0.816
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...  Hotel     0.000
# [279] Jaccard~hotel_name-T:0.2/S:true/B:false/L...  Hotel     0.000
# [194] JaccardOnBiGrams~streetaddress-T:0.2/S:fa...  Hotel     0.943
# [282] JaccardOnBiGrams~hotel_name-T:0.0/S:true/...  Hotel     0.000
# [281] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...  Hotel     0.000
# [178] Levenshtein~streetaddress-T:0.2/S:false/B...  Hotel     0.000
# [278] Jaccard~hotel_name-T:0.2/S:false/B:true/L...  Hotel     0.000
# [218] Levenshtein~postalcode-T:0.4/S:true/B:tru...  Hotel     0.000
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...  Hotel     0.000
# [108] JaccardOnBiGrams~infrequent_part_hotel_na...  Hotel     0.000
# [38] Jaro~frequent_part_hotel_name-T:0.8/S:true...  Hotel     0.000
# [197] FirstCharacter~streetaddress-T:0.0/S:fals...  Hotel     0.000
# [296] JaroWinkler~hotel_name-T:0.2/S:true/B:fal...  Hotel     0.000
# [301] Jaro~hotel_name-T:0.6/S:true/B:true/L:true    Hotel     0.000
#
#                                                     logOdds_std
# Feature
# [175] Levenshtein~streetaddress-T:0.4/S:true/B:...        0.000
# [260] BagOfWordsContainment~all-T:0.4/L:true              1.937
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...        0.000
# [279] Jaccard~hotel_name-T:0.2/S:true/B:false/L...        0.000
# [194] JaccardOnBiGrams~streetaddress-T:0.2/S:fa...        0.293
# [282] JaccardOnBiGrams~hotel_name-T:0.0/S:true/...        0.000
# [281] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...        0.000
# [178] Levenshtein~streetaddress-T:0.2/S:false/B...        0.000
# [278] Jaccard~hotel_name-T:0.2/S:false/B:true/L...        0.000
# [218] Levenshtein~postalcode-T:0.4/S:true/B:tru...        0.000
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...        0.000
# [108] JaccardOnBiGrams~infrequent_part_hotel_na...        0.000
# [38] Jaro~frequent_part_hotel_name-T:0.8/S:true...        0.000
# [197] FirstCharacter~streetaddress-T:0.0/S:fals...        0.000
# [296] JaroWinkler~hotel_name-T:0.2/S:true/B:fal...        0.000
# [301] Jaro~hotel_name-T:0.6/S:true/B:true/L:true          0.000
# \begin{tabular}{lrrlrr}
# \toprule
# {} &  Rank\_mean &  logOdds\_mean &  Topic &  Rank\_std &  logOdds\_std \\
# Feature                                            &            &               &        &           &              \\
# \midrule
# [175] Levenshtein\textasciitilde streetaddress-T:0.4/S:true/B:... &      1.000 &         7.889 &  Hotel &     0.000 &        0.000 \\
# [260] BagOfWordsContainment\textasciitilde all-T:0.4/L:true       &      2.000 &         4.430 &  Hotel &     0.816 &        1.937 \\
# [287] JaccardOnBiGrams\textasciitilde hotel\_name-T:0.2/S:true/... &      1.000 &         3.537 &  Hotel &     0.000 &        0.000 \\
# [279] Jaccard\textasciitilde hotel\_name-T:0.2/S:true/B:false/L... &      1.000 &         2.760 &  Hotel &     0.000 &        0.000 \\
# [194] JaccardOnBiGrams\textasciitilde streetaddress-T:0.2/S:fa... &      2.667 &         2.688 &  Hotel &     0.943 &        0.293 \\
# [282] JaccardOnBiGrams\textasciitilde hotel\_name-T:0.0/S:true/... &      3.000 &         2.682 &  Hotel &     0.000 &        0.000 \\
# [281] JaccardOnBiGrams\textasciitilde hotel\_name-T:0.2/S:true/... &      3.000 &         2.388 &  Hotel &     0.000 &        0.000 \\
# [178] Levenshtein\textasciitilde streetaddress-T:0.2/S:false/B... &      4.000 &         2.365 &  Hotel &     0.000 &        0.000 \\
# [278] Jaccard\textasciitilde hotel\_name-T:0.2/S:false/B:true/L... &      5.000 &         2.099 &  Hotel &     0.000 &        0.000 \\
# [218] Levenshtein\textasciitilde postalcode-T:0.4/S:true/B:tru... &      5.000 &         2.011 &  Hotel &     0.000 &        0.000 \\
# [19] JaccardOnBiGrams\textasciitilde frequent\_part\_hotel\_name-... &      2.000 &         1.253 &  Hotel &     0.000 &        0.000 \\
# [108] JaccardOnBiGrams\textasciitilde infrequent\_part\_hotel\_na... &      4.000 &         1.229 &  Hotel &     0.000 &        0.000 \\
# [38] Jaro\textasciitilde frequent\_part\_hotel\_name-T:0.8/S:true... &      5.000 &        -1.183 &  Hotel &     0.000 &        0.000 \\
# [197] FirstCharacter\textasciitilde streetaddress-T:0.0/S:fals... &      6.000 &        -1.812 &  Hotel &     0.000 &        0.000 \\
# [296] JaroWinkler\textasciitilde hotel\_name-T:0.2/S:true/B:fal... &      7.000 &       -11.214 &  Hotel &     0.000 &        0.000 \\
# [301] Jaro\textasciitilde hotel\_name-T:0.6/S:true/B:true/L:true   &      6.000 &       -20.451 &  Hotel &     0.000 &        0.000 \\
# \bottomrule
# \end{tabular}
# 'FeatureThreshold_importance_J48'
#                                                    Rank_mean  \
# FeatureThreshold
# BagOfWordsContainment~all-T:0.4                            1
# JaccardOnBiGrams~frequent_part_hotel_name-T:0.4            1
# JaccardOnBiGrams~hotel_name-T:0.2                          2
# JaroWinkler~postalcode-T:0.8                               2
# Jaccard~streetaddress-T:0.2                                2
# Equal~infrequent_part_hotel_name-T:0.0                     2
# JaccardOnBiGrams~infrequent_part_hotel_name-T:0.4          3
# Jaccard~infrequent_part_hotel_name-T:0.4                   2
# Jaccard~streetaddress-T:0.4                                4
# BagOfWordsContainment~all-T:0.2                            5
# Jaccard~addresslocality-T:0.2                              6
# JaccardOnBiGrams~streetaddress-T:0.0                       7
#
#                                                    GainRatioImportance_mean  \
# FeatureThreshold
# BagOfWordsContainment~all-T:0.4                                       0.773
# JaccardOnBiGrams~frequent_part_hotel_name-T:0.4                       0.402
# JaccardOnBiGrams~hotel_name-T:0.2                                     0.272
# JaroWinkler~postalcode-T:0.8                                          0.267
# Jaccard~streetaddress-T:0.2                                           0.186
# Equal~infrequent_part_hotel_name-T:0.0                                0.124
# JaccardOnBiGrams~infrequent_part_hotel_name-T:0.4                     0.109
# Jaccard~infrequent_part_hotel_name-T:0.4                              0.043
# Jaccard~streetaddress-T:0.4                                           0.026
# BagOfWordsContainment~all-T:0.2                                       0.018
# Jaccard~addresslocality-T:0.2                                         0.010
# JaccardOnBiGrams~streetaddress-T:0.0                                  0.005
#
#                                                    Topic  Rank_std  \
# FeatureThreshold
# BagOfWordsContainment~all-T:0.4                    Hotel       0.0
# JaccardOnBiGrams~frequent_part_hotel_name-T:0.4    Hotel       0.0
# JaccardOnBiGrams~hotel_name-T:0.2                  Hotel       1.0
# JaroWinkler~postalcode-T:0.8                       Hotel       0.0
# Jaccard~streetaddress-T:0.2                        Hotel       0.0
# Equal~infrequent_part_hotel_name-T:0.0             Hotel       0.0
# JaccardOnBiGrams~infrequent_part_hotel_name-T:0.4  Hotel       0.0
# Jaccard~infrequent_part_hotel_name-T:0.4           Hotel       0.0
# Jaccard~streetaddress-T:0.4                        Hotel       0.0
# BagOfWordsContainment~all-T:0.2                    Hotel       0.0
# Jaccard~addresslocality-T:0.2                      Hotel       0.0
# JaccardOnBiGrams~streetaddress-T:0.0               Hotel       0.0
#
#                                                    GainRatioImportance_std
# FeatureThreshold
# BagOfWordsContainment~all-T:0.4                                      0.001
# JaccardOnBiGrams~frequent_part_hotel_name-T:0.4                      0.000
# JaccardOnBiGrams~hotel_name-T:0.2                                    0.241
# JaroWinkler~postalcode-T:0.8                                         0.000
# Jaccard~streetaddress-T:0.2                                          0.000
# Equal~infrequent_part_hotel_name-T:0.0                               0.000
# JaccardOnBiGrams~infrequent_part_hotel_name-T:0.4                    0.000
# Jaccard~infrequent_part_hotel_name-T:0.4                             0.000
# Jaccard~streetaddress-T:0.4                                          0.000
# BagOfWordsContainment~all-T:0.2                                      0.000
# Jaccard~addresslocality-T:0.2                                        0.000
# JaccardOnBiGrams~streetaddress-T:0.0                                 0.000
# \begin{tabular}{lrrlrr}
# \toprule
# {} &  Rank\_mean &  GainRatioImportance\_mean &  Topic &  Rank\_std &  GainRatioImportance\_std \\
# FeatureThreshold                                  &            &                           &        &           &                          \\
# \midrule
# BagOfWordsContainment\textasciitilde all-T:0.4                   &          1 &                     0.773 &  Hotel &       0.0 &                    0.001 \\
# JaccardOnBiGrams\textasciitilde frequent\_part\_hotel\_name-T:0.4   &          1 &                     0.402 &  Hotel &       0.0 &                    0.000 \\
# JaccardOnBiGrams\textasciitilde hotel\_name-T:0.2                 &          2 &                     0.272 &  Hotel &       1.0 &                    0.241 \\
# JaroWinkler\textasciitilde postalcode-T:0.8                      &          2 &                     0.267 &  Hotel &       0.0 &                    0.000 \\
# Jaccard\textasciitilde streetaddress-T:0.2                       &          2 &                     0.186 &  Hotel &       0.0 &                    0.000 \\
# Equal\textasciitilde infrequent\_part\_hotel\_name-T:0.0            &          2 &                     0.124 &  Hotel &       0.0 &                    0.000 \\
# JaccardOnBiGrams\textasciitilde infrequent\_part\_hotel\_name-T:0.4 &          3 &                     0.109 &  Hotel &       0.0 &                    0.000 \\
# Jaccard\textasciitilde infrequent\_part\_hotel\_name-T:0.4          &          2 &                     0.043 &  Hotel &       0.0 &                    0.000 \\
# Jaccard\textasciitilde streetaddress-T:0.4                       &          4 &                     0.026 &  Hotel &       0.0 &                    0.000 \\
# BagOfWordsContainment\textasciitilde all-T:0.2                   &          5 &                     0.018 &  Hotel &       0.0 &                    0.000 \\
# Jaccard\textasciitilde addresslocality-T:0.2                     &          6 &                     0.010 &  Hotel &       0.0 &                    0.000 \\
# JaccardOnBiGrams\textasciitilde streetaddress-T:0.0              &          7 &                     0.005 &  Hotel &       0.0 &                    0.000 \\
# \bottomrule
# \end{tabular}
# 'Feature_importance_J48'
#                                                     Rank_mean  \
# Feature
# [260] BagOfWordsContainment~all-T:0.4/L:true                1
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...          1
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...          1
# [245] JaroWinkler~postalcode-T:0.8/S:true/B:tru...          2
# [186] Jaccard~streetaddress-T:0.2/S:false/B:tru...          2
# [86] Equal~infrequent_part_hotel_name-T:0.0/S:f...          2
# [105] JaccardOnBiGrams~infrequent_part_hotel_na...          3
# [97] Jaccard~infrequent_part_hotel_name-T:0.4/S...          2
# [286] JaccardOnBiGrams~hotel_name-T:0.2/S:false...          3
# [183] Jaccard~streetaddress-T:0.4/S:true/B:true...          4
# [263] BagOfWordsContainment~all-T:0.2/L:false               5
# [52] Jaccard~addresslocality-T:0.2/S:true/B:tru...          6
# [190] JaccardOnBiGrams~streetaddress-T:0.0/S:tr...          7
#
#                                                     GainRatioImportance_mean  \
# Feature
# [260] BagOfWordsContainment~all-T:0.4/L:true                           0.773
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...                     0.514
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...                     0.402
# [245] JaroWinkler~postalcode-T:0.8/S:true/B:tru...                     0.267
# [186] Jaccard~streetaddress-T:0.2/S:false/B:tru...                     0.186
# [86] Equal~infrequent_part_hotel_name-T:0.0/S:f...                     0.124
# [105] JaccardOnBiGrams~infrequent_part_hotel_na...                     0.109
# [97] Jaccard~infrequent_part_hotel_name-T:0.4/S...                     0.043
# [286] JaccardOnBiGrams~hotel_name-T:0.2/S:false...                     0.031
# [183] Jaccard~streetaddress-T:0.4/S:true/B:true...                     0.026
# [263] BagOfWordsContainment~all-T:0.2/L:false                          0.018
# [52] Jaccard~addresslocality-T:0.2/S:true/B:tru...                     0.010
# [190] JaccardOnBiGrams~streetaddress-T:0.0/S:tr...                     0.005
#
#                                                     Topic  Rank_std  \
# Feature
# [260] BagOfWordsContainment~all-T:0.4/L:true        Hotel       0.0
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...  Hotel       0.0
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...  Hotel       0.0
# [245] JaroWinkler~postalcode-T:0.8/S:true/B:tru...  Hotel       0.0
# [186] Jaccard~streetaddress-T:0.2/S:false/B:tru...  Hotel       0.0
# [86] Equal~infrequent_part_hotel_name-T:0.0/S:f...  Hotel       0.0
# [105] JaccardOnBiGrams~infrequent_part_hotel_na...  Hotel       0.0
# [97] Jaccard~infrequent_part_hotel_name-T:0.4/S...  Hotel       0.0
# [286] JaccardOnBiGrams~hotel_name-T:0.2/S:false...  Hotel       0.0
# [183] Jaccard~streetaddress-T:0.4/S:true/B:true...  Hotel       0.0
# [263] BagOfWordsContainment~all-T:0.2/L:false       Hotel       0.0
# [52] Jaccard~addresslocality-T:0.2/S:true/B:tru...  Hotel       0.0
# [190] JaccardOnBiGrams~streetaddress-T:0.0/S:tr...  Hotel       0.0
#
#                                                     GainRatioImportance_std
# Feature
# [260] BagOfWordsContainment~all-T:0.4/L:true                          0.001
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...                    0.000
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...                    0.000
# [245] JaroWinkler~postalcode-T:0.8/S:true/B:tru...                    0.000
# [186] Jaccard~streetaddress-T:0.2/S:false/B:tru...                    0.000
# [86] Equal~infrequent_part_hotel_name-T:0.0/S:f...                    0.000
# [105] JaccardOnBiGrams~infrequent_part_hotel_na...                    0.000
# [97] Jaccard~infrequent_part_hotel_name-T:0.4/S...                    0.000
# [286] JaccardOnBiGrams~hotel_name-T:0.2/S:false...                    0.000
# [183] Jaccard~streetaddress-T:0.4/S:true/B:true...                    0.000
# [263] BagOfWordsContainment~all-T:0.2/L:false                         0.000
# [52] Jaccard~addresslocality-T:0.2/S:true/B:tru...                    0.000
# [190] JaccardOnBiGrams~streetaddress-T:0.0/S:tr...                    0.000
# \begin{tabular}{lrrlrr}
# \toprule
# {} &  Rank\_mean &  GainRatioImportance\_mean &  Topic &  Rank\_std &  GainRatioImportance\_std \\
# Feature                                            &            &                           &        &           &                          \\
# \midrule
# [260] BagOfWordsContainment\textasciitilde all-T:0.4/L:true       &          1 &                     0.773 &  Hotel &       0.0 &                    0.001 \\
# [287] JaccardOnBiGrams\textasciitilde hotel\_name-T:0.2/S:true/... &          1 &                     0.514 &  Hotel &       0.0 &                    0.000 \\
# [19] JaccardOnBiGrams\textasciitilde frequent\_part\_hotel\_name-... &          1 &                     0.402 &  Hotel &       0.0 &                    0.000 \\
# [245] JaroWinkler\textasciitilde postalcode-T:0.8/S:true/B:tru... &          2 &                     0.267 &  Hotel &       0.0 &                    0.000 \\
# [186] Jaccard\textasciitilde streetaddress-T:0.2/S:false/B:tru... &          2 &                     0.186 &  Hotel &       0.0 &                    0.000 \\
# [86] Equal\textasciitilde infrequent\_part\_hotel\_name-T:0.0/S:f... &          2 &                     0.124 &  Hotel &       0.0 &                    0.000 \\
# [105] JaccardOnBiGrams\textasciitilde infrequent\_part\_hotel\_na... &          3 &                     0.109 &  Hotel &       0.0 &                    0.000 \\
# [97] Jaccard\textasciitilde infrequent\_part\_hotel\_name-T:0.4/S... &          2 &                     0.043 &  Hotel &       0.0 &                    0.000 \\
# [286] JaccardOnBiGrams\textasciitilde hotel\_name-T:0.2/S:false... &          3 &                     0.031 &  Hotel &       0.0 &                    0.000 \\
# [183] Jaccard\textasciitilde streetaddress-T:0.4/S:true/B:true... &          4 &                     0.026 &  Hotel &       0.0 &                    0.000 \\
# [263] BagOfWordsContainment\textasciitilde all-T:0.2/L:false      &          5 &                     0.018 &  Hotel &       0.0 &                    0.000 \\
# [52] Jaccard\textasciitilde addresslocality-T:0.2/S:true/B:tru... &          6 &                     0.010 &  Hotel &       0.0 &                    0.000 \\
# [190] JaccardOnBiGrams\textasciitilde streetaddress-T:0.0/S:tr... &          7 &                     0.005 &  Hotel &       0.0 &                    0.000 \\
# \bottomrule
# \end{tabular}
# 'FeatureThreshold_Odds_importance_SimpleLogistic'
#                                                    Rank_mean  logOdds_mean  \
# FeatureThreshold
# Levenshtein~streetaddress-T:0.4                        1.000         7.889
# BagOfWordsContainment~all-T:0.4                        2.000         4.430
# JaccardOnBiGrams~hotel_name-T:0.2                      2.000         2.963
# JaccardOnBiGrams~streetaddress-T:0.2                   2.667         2.688
# JaccardOnBiGrams~hotel_name-T:0.0                      3.000         2.682
# Jaccard~hotel_name-T:0.2                               3.000         2.429
# Levenshtein~streetaddress-T:0.2                        4.000         2.365
# Levenshtein~postalcode-T:0.4                           5.000         2.011
# JaccardOnBiGrams~frequent_part_hotel_name-T:0.4        2.000         1.253
# JaccardOnBiGrams~infrequent_part_hotel_name-T:0.2      4.000         1.229
# Jaro~frequent_part_hotel_name-T:0.8                    5.000        -1.183
# FirstCharacter~streetaddress-T:0.0                     6.000        -1.812
# JaroWinkler~hotel_name-T:0.2                           7.000       -11.214
# Jaro~hotel_name-T:0.6                                  6.000       -20.451
#
#                                                    Topic  Rank_std  \
# FeatureThreshold
# Levenshtein~streetaddress-T:0.4                    Hotel     0.000
# BagOfWordsContainment~all-T:0.4                    Hotel     0.816
# JaccardOnBiGrams~hotel_name-T:0.2                  Hotel     1.000
# JaccardOnBiGrams~streetaddress-T:0.2               Hotel     0.943
# JaccardOnBiGrams~hotel_name-T:0.0                  Hotel     0.000
# Jaccard~hotel_name-T:0.2                           Hotel     2.000
# Levenshtein~streetaddress-T:0.2                    Hotel     0.000
# Levenshtein~postalcode-T:0.4                       Hotel     0.000
# JaccardOnBiGrams~frequent_part_hotel_name-T:0.4    Hotel     0.000
# JaccardOnBiGrams~infrequent_part_hotel_name-T:0.2  Hotel     0.000
# Jaro~frequent_part_hotel_name-T:0.8                Hotel     0.000
# FirstCharacter~streetaddress-T:0.0                 Hotel     0.000
# JaroWinkler~hotel_name-T:0.2                       Hotel     0.000
# Jaro~hotel_name-T:0.6                              Hotel     0.000
#
#                                                    logOdds_std
# FeatureThreshold
# Levenshtein~streetaddress-T:0.4                          0.000
# BagOfWordsContainment~all-T:0.4                          1.937
# JaccardOnBiGrams~hotel_name-T:0.2                        0.575
# JaccardOnBiGrams~streetaddress-T:0.2                     0.293
# JaccardOnBiGrams~hotel_name-T:0.0                        0.000
# Jaccard~hotel_name-T:0.2                                 0.330
# Levenshtein~streetaddress-T:0.2                          0.000
# Levenshtein~postalcode-T:0.4                             0.000
# JaccardOnBiGrams~frequent_part_hotel_name-T:0.4          0.000
# JaccardOnBiGrams~infrequent_part_hotel_name-T:0.2        0.000
# Jaro~frequent_part_hotel_name-T:0.8                      0.000
# FirstCharacter~streetaddress-T:0.0                       0.000
# JaroWinkler~hotel_name-T:0.2                             0.000
# Jaro~hotel_name-T:0.6                                    0.000
# \begin{tabular}{lrrlrr}
# \toprule
# {} &  Rank\_mean &  logOdds\_mean &  Topic &  Rank\_std &  logOdds\_std \\
# FeatureThreshold                                  &            &               &        &           &              \\
# \midrule
# Levenshtein\textasciitilde streetaddress-T:0.4                   &      1.000 &         7.889 &  Hotel &     0.000 &        0.000 \\
# BagOfWordsContainment\textasciitilde all-T:0.4                   &      2.000 &         4.430 &  Hotel &     0.816 &        1.937 \\
# JaccardOnBiGrams\textasciitilde hotel\_name-T:0.2                 &      2.000 &         2.963 &  Hotel &     1.000 &        0.575 \\
# JaccardOnBiGrams\textasciitilde streetaddress-T:0.2              &      2.667 &         2.688 &  Hotel &     0.943 &        0.293 \\
# JaccardOnBiGrams\textasciitilde hotel\_name-T:0.0                 &      3.000 &         2.682 &  Hotel &     0.000 &        0.000 \\
# Jaccard\textasciitilde hotel\_name-T:0.2                          &      3.000 &         2.429 &  Hotel &     2.000 &        0.330 \\
# Levenshtein\textasciitilde streetaddress-T:0.2                   &      4.000 &         2.365 &  Hotel &     0.000 &        0.000 \\
# Levenshtein\textasciitilde postalcode-T:0.4                      &      5.000 &         2.011 &  Hotel &     0.000 &        0.000 \\
# JaccardOnBiGrams\textasciitilde frequent\_part\_hotel\_name-T:0.4   &      2.000 &         1.253 &  Hotel &     0.000 &        0.000 \\
# JaccardOnBiGrams\textasciitilde infrequent\_part\_hotel\_name-T:0.2 &      4.000 &         1.229 &  Hotel &     0.000 &        0.000 \\
# Jaro\textasciitilde frequent\_part\_hotel\_name-T:0.8               &      5.000 &        -1.183 &  Hotel &     0.000 &        0.000 \\
# FirstCharacter\textasciitilde streetaddress-T:0.0                &      6.000 &        -1.812 &  Hotel &     0.000 &        0.000 \\
# JaroWinkler\textasciitilde hotel\_name-T:0.2                      &      7.000 &       -11.214 &  Hotel &     0.000 &        0.000 \\
# Jaro\textasciitilde hotel\_name-T:0.6                             &      6.000 &       -20.451 &  Hotel &     0.000 &        0.000 \\
# \bottomrule
# \end{tabular}
# 'SplitThreshold_importance_J48'
#                                                     Rank_mean  \
# SplitThreshold
# [260] BagOfWordsContainment~all-T:0.4/L:true~0.4            1
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...          1
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...          1
# [245] JaroWinkler~postalcode-T:0.8/S:true/B:tru...          2
# [186] Jaccard~streetaddress-T:0.2/S:false/B:tru...          2
# [86] Equal~infrequent_part_hotel_name-T:0.0/S:f...          2
# [105] JaccardOnBiGrams~infrequent_part_hotel_na...          3
# [97] Jaccard~infrequent_part_hotel_name-T:0.4/S...          2
# [286] JaccardOnBiGrams~hotel_name-T:0.2/S:false...          3
# [183] Jaccard~streetaddress-T:0.4/S:true/B:true...          4
# [263] BagOfWordsContainment~all-T:0.2/L:false~0.5           5
# [52] Jaccard~addresslocality-T:0.2/S:true/B:tru...          6
# [190] JaccardOnBiGrams~streetaddress-T:0.0/S:tr...          7
#
#                                                     GainRatioImportance_mean  \
# SplitThreshold
# [260] BagOfWordsContainment~all-T:0.4/L:true~0.4                       0.773
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...                     0.514
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...                     0.402
# [245] JaroWinkler~postalcode-T:0.8/S:true/B:tru...                     0.267
# [186] Jaccard~streetaddress-T:0.2/S:false/B:tru...                     0.186
# [86] Equal~infrequent_part_hotel_name-T:0.0/S:f...                     0.124
# [105] JaccardOnBiGrams~infrequent_part_hotel_na...                     0.109
# [97] Jaccard~infrequent_part_hotel_name-T:0.4/S...                     0.043
# [286] JaccardOnBiGrams~hotel_name-T:0.2/S:false...                     0.031
# [183] Jaccard~streetaddress-T:0.4/S:true/B:true...                     0.026
# [263] BagOfWordsContainment~all-T:0.2/L:false~0.5                      0.018
# [52] Jaccard~addresslocality-T:0.2/S:true/B:tru...                     0.010
# [190] JaccardOnBiGrams~streetaddress-T:0.0/S:tr...                     0.005
#
#                                                     Topic  Rank_std  \
# SplitThreshold
# [260] BagOfWordsContainment~all-T:0.4/L:true~0.4    Hotel       0.0
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...  Hotel       0.0
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...  Hotel       0.0
# [245] JaroWinkler~postalcode-T:0.8/S:true/B:tru...  Hotel       0.0
# [186] Jaccard~streetaddress-T:0.2/S:false/B:tru...  Hotel       0.0
# [86] Equal~infrequent_part_hotel_name-T:0.0/S:f...  Hotel       0.0
# [105] JaccardOnBiGrams~infrequent_part_hotel_na...  Hotel       0.0
# [97] Jaccard~infrequent_part_hotel_name-T:0.4/S...  Hotel       0.0
# [286] JaccardOnBiGrams~hotel_name-T:0.2/S:false...  Hotel       0.0
# [183] Jaccard~streetaddress-T:0.4/S:true/B:true...  Hotel       0.0
# [263] BagOfWordsContainment~all-T:0.2/L:false~0.5   Hotel       0.0
# [52] Jaccard~addresslocality-T:0.2/S:true/B:tru...  Hotel       0.0
# [190] JaccardOnBiGrams~streetaddress-T:0.0/S:tr...  Hotel       0.0
#
#                                                     GainRatioImportance_std
# SplitThreshold
# [260] BagOfWordsContainment~all-T:0.4/L:true~0.4                      0.001
# [287] JaccardOnBiGrams~hotel_name-T:0.2/S:true/...                    0.000
# [19] JaccardOnBiGrams~frequent_part_hotel_name-...                    0.000
# [245] JaroWinkler~postalcode-T:0.8/S:true/B:tru...                    0.000
# [186] Jaccard~streetaddress-T:0.2/S:false/B:tru...                    0.000
# [86] Equal~infrequent_part_hotel_name-T:0.0/S:f...                    0.000
# [105] JaccardOnBiGrams~infrequent_part_hotel_na...                    0.000
# [97] Jaccard~infrequent_part_hotel_name-T:0.4/S...                    0.000
# [286] JaccardOnBiGrams~hotel_name-T:0.2/S:false...                    0.000
# [183] Jaccard~streetaddress-T:0.4/S:true/B:true...                    0.000
# [263] BagOfWordsContainment~all-T:0.2/L:false~0.5                     0.000
# [52] Jaccard~addresslocality-T:0.2/S:true/B:tru...                    0.000
# [190] JaccardOnBiGrams~streetaddress-T:0.0/S:tr...                    0.000
# \begin{tabular}{lrrlrr}
# \toprule
# {} &  Rank\_mean &  GainRatioImportance\_mean &  Topic &  Rank\_std &  GainRatioImportance\_std \\
# SplitThreshold                                     &            &                           &        &           &                          \\
# \midrule
# [260] BagOfWordsContainment\textasciitilde all-T:0.4/L:true\textasciitilde 0.4   &          1 &                     0.773 &  Hotel &       0.0 &                    0.001 \\
# [287] JaccardOnBiGrams\textasciitilde hotel\_name-T:0.2/S:true/... &          1 &                     0.514 &  Hotel &       0.0 &                    0.000 \\
# [19] JaccardOnBiGrams\textasciitilde frequent\_part\_hotel\_name-... &          1 &                     0.402 &  Hotel &       0.0 &                    0.000 \\
# [245] JaroWinkler\textasciitilde postalcode-T:0.8/S:true/B:tru... &          2 &                     0.267 &  Hotel &       0.0 &                    0.000 \\
# [186] Jaccard\textasciitilde streetaddress-T:0.2/S:false/B:tru... &          2 &                     0.186 &  Hotel &       0.0 &                    0.000 \\
# [86] Equal\textasciitilde infrequent\_part\_hotel\_name-T:0.0/S:f... &          2 &                     0.124 &  Hotel &       0.0 &                    0.000 \\
# [105] JaccardOnBiGrams\textasciitilde infrequent\_part\_hotel\_na... &          3 &                     0.109 &  Hotel &       0.0 &                    0.000 \\
# [97] Jaccard\textasciitilde infrequent\_part\_hotel\_name-T:0.4/S... &          2 &                     0.043 &  Hotel &       0.0 &                    0.000 \\
# [286] JaccardOnBiGrams\textasciitilde hotel\_name-T:0.2/S:false... &          3 &                     0.031 &  Hotel &       0.0 &                    0.000 \\
# [183] Jaccard\textasciitilde streetaddress-T:0.4/S:true/B:true... &          4 &                     0.026 &  Hotel &       0.0 &                    0.000 \\
# [263] BagOfWordsContainment\textasciitilde all-T:0.2/L:false\textasciitilde 0.5  &          5 &                     0.018 &  Hotel &       0.0 &                    0.000 \\
# [52] Jaccard\textasciitilde addresslocality-T:0.2/S:true/B:tru... &          6 &                     0.010 &  Hotel &       0.0 &                    0.000 \\
# [190] JaccardOnBiGrams\textasciitilde streetaddress-T:0.0/S:tr... &          7 &                     0.005 &  Hotel &       0.0 &                    0.000 \\
# \bottomrule
# \end{tabular}
